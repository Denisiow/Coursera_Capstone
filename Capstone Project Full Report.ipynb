# %% [markdown]
# # The Battle of Neighborhoods
# ## Introduction

# %% [markdown]
# ### Business Proposal
# In this project we'll try to figure out which neighborhoods in Broklyn, NY are the best to establish a bakery/coffee shop. We'll focus on the neighborhoods where bakeries are not a common place and are not near the beach.
#
# The aim of the project is to make it easier for franchise owners or people starting a new business to find a suitable neighborhood to open a new bakery & coffee shop in Brooklyn

# %% [markdown]
# ### Location

# %% [markdown]
# Brooklyn is the most populous borough in New York City and is known for its cultural, social, and ethnic diversity, and for its distinct neighborhoods. For this reasons Brooklyn is a great place to establish our business.

# %% [markdown]
# ![map.jpg](attachment:map.jpg)

# %% [markdown]
# ### Foursquare API

# %% [markdown]
# This project would use Four-square API as its prime data gathering source as it has a database of millions of places, especially their places API which provides the ability to perform location search, location sharing and details about a business.

# %% [markdown]
# ### Libraries used

# %% [markdown]
# **Pandas:** For creating and manipulating dataframes.
#
# **Folium:** Python visualization library would be used to visualize the neighborhoods cluster distribution or using interactive leaflet map.
#
# **JSON:** Library to handle JSON files.
#
# **Geocoder:** To retrieve Location Data.
#
# **Matplotlib:** Python Plotting Module.

# %% [markdown]
# ## Data used

# %% [markdown]
# ### Data Description

# %% [markdown]
# Link: https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json
#
# We'll use this New York Neighborhoods dataset, which has all the required geographical locations and names of the neighborhoods

# %% [markdown]
# ### Foursquare API

# %% [markdown]
# We will need data about different venues in different neighborhoods of that specific borough. In order to gain that information we will use "Foursquare" locational information. Foursquare is a location data provider with information about all manner of venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. As such, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
# After finding the list of neighborhoods, we then connect to the Foursquare API to gather information about venues inside each and every neighborhood. For each neighborhood, we have chosen the radius to be 350 meter.
#
# The data retrieved from Foursquare contained information of venues within a specified distance of the longitude and latitude of the neighborhoods. The information obtained for every venue is:
#
# 1. Neighborhood
# 2. Neighborhood Latitude
# 3. Neighborhood Longitude
# 4. Venue
# 5. Name of the venue e.g. the name of a store or restaurant
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category

# %% [markdown]
# ## Results

# %% [markdown]
# We end up with a list of 18 possible locations where we could establish our bakery, which can be narrowed down depending on other priorities

# %% [markdown]
# ![possible.jpg](attachment:possible.jpg)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Thanks to the integration with the Foursquare API we are able to look for and segment different locations on where we could establish our business without much competition
